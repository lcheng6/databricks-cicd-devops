# %%
def external_notebook_function() -> int: 
  return 3

# %% [markdown]
# path of this notebooks is
# ```
# /Workspace/Users/liang.cheng@databricks.com/databricks-cicd-devops/notebooks/library/external_notebook_functions
# ```
